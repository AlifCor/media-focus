# %%
import process_data
import datetime
import json

# %%
process_data.compute_processed_data(start=datetime.datetime(2017, 12, 4),name="data_cleaned")

# %%
with open("../data/countries.json", "r") as f:
    countries = json.load(f)

# %%
to_store = dict([(country["cca3"], country["latlng"]) for country in countries])

# %%
to_store
# Out:
# {'ABW': [12.5, -69.96666666],
#  'AFG': [33, 65],
#  'AGO': [-12.5, 18.5],
#  'AIA': [18.25, -63.16666666],
#  'ALA': [60.116667, 19.9],
#  'ALB': [41, 20],
#  'AND': [42.5, 1.5],
#  'ARE': [24, 54],
#  'ARG': [-34, -64],
#  'ARM': [40, 45],
#  'ASM': [-14.33333333, -170],
#  'ATA': [-90, 0],
#  'ATF': [-49.25, 69.167],
#  'ATG': [17.05, -61.8],
#  'AUS': [-27, 133],
#  'AUT': [47.33333333, 13.33333333],
#  'AZE': [40.5, 47.5],
#  'BDI': [-3.5, 30],
#  'BEL': [50.83333333, 4],
#  'BEN': [9.5, 2.25],
#  'BFA': [13, -2],
#  'BGD': [24, 90],
#  'BGR': [43, 25],
#  'BHR': [26, 50.55],
#  'BHS': [24.25, -76],
#  'BIH': [44, 18],
#  'BLM': [18.5, -63.41666666],
#  'BLR': [53, 28],
#  'BLZ': [17.25, -88.75],
#  'BMU': [32.33333333, -64.75],
#  'BOL': [-17, -65],
#  'BRA': [-10, -55],
#  'BRB': [13.16666666, -59.53333333],
#  'BRN': [4.5, 114.66666666],
#  'BTN': [27.5, 90.5],
#  'BVT': [-54.43333333, 3.4],
#  'BWA': [-22, 24],
#  'CAF': [7, 21],
#  'CAN': [60, -95],
# ...

# %%
with open("../../data/countries_latlng.json", "w") as f:
    json.dump(to_store, f)
